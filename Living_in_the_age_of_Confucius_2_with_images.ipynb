# %%
html_content = r"""<!DOCTYPE html>
<html lang="en">
<head>
  <meta charset="UTF-8" />
  <title>Living in the Confucius Era</title>
  <meta name="viewport" content="width=device-width, initial-scale=1" />
  <link href="https://fonts.googleapis.com/css2?family=Crimson+Pro:wght@400;600&family=Zilla+Slab:wght@300;500&display=swap" rel="stylesheet">
  <style>
    :root {
      --bg-color: #1a1a1a;
      --paper-color: #f4f1ea;
      --accent-color: #8b0000;
      --text-color: #2c2c2c;
    }

    body {
      font-family: 'Crimson Pro', serif;
      margin: 0;
      padding: 0;
      background: var(--bg-color);
      color: var(--paper-color);
      display: flex;
      justify-content: center;
      align-items: center;
      min-height: 100vh;
    }

    .container {
      max-width: 800px;
      width: 90%;
      padding: 3rem;
      background: var(--paper-color);
      color: var(--text-color);
      border-radius: 2px;
      box-shadow: 0 10px 30px rgba(0,0,0,0.5);
      position: relative;
      transition: opacity 0.5s ease;
    }

    /* Image Styling */
    #scene-image {
      width: 100%;
      max-height: 400px;
      object-fit: cover;
      border-radius: 4px;
      margin-bottom: 2rem;
      display: none; /* Hidden by default, shown if URL exists */
    }

    h1 {
      font-family: 'Zilla Slab', serif;
      text-align: center;
      color: var(--accent-color);
      margin-bottom: 2rem;
    }

    #scene-text {
      font-size: 1.25rem;
      line-height: 1.8;
      margin-bottom: 2.5rem;
      white-space: pre-line;
    }

    .choices { display: flex; flex-direction: column; gap: 1rem; }

    .choices button {
      padding: 1rem;
      background: transparent;
      border: 1px solid #ccc;
      cursor: pointer;
      transition: all 0.3s ease;
      text-align: left;
      font-family: 'Crimson Pro', serif;
      font-size: 1.1rem;
    }

    .choices button:hover {
      background: var(--accent-color);
      color: white;
      padding-left: 2rem;
    }

    #restart-btn {
      margin-top: 3rem;
      background: none;
      border: none;
      color: #999;
      cursor: pointer;
      text-decoration: underline;
      width: 100%;
    }
  </style>
</head>
<body>
  <div class="container" id="game-container">
    <h1>Living in Age of Confucius</h1>

    <!-- Added the Image Tag here -->
    <img id="scene-image" alt="Scene Illustration">

    <div id="scene-title" style="font-weight:bold; color:#666; margin-bottom:10px;"></div>
    <div id="scene-text"></div>
    <div class="choices" id="choices"></div>
    <button id="restart-btn" type="button">Return to the Beginning</button>
  </div>

  <script>
    const scenes = {
      start: {
        title: "770BCE-221BCE | Middle China",
        image: "https://www.merit-times.com.tw/news_pic/20220514/C20220513211902840.jpg",
        text: "You are an eighteen-year-old educated male reading the Analects of Confucius and other masters' thoughts.\n\nOne day, you went into the Jixia Academy, where people from different schools debate with each other. Someone asked: 'Is human nature fundamentally evil or fundamentally good?'",
        choices: [
          { text: "Being evil because we are having endless warfare between vassals now.", next: "Evil" },
          { text: "Being good because everyone was born with the capacity to recognize what is right.", next: "Good_attempt" }
        ]
      },
      Evil: {
        title: "Being Evil",
        image: "https://pic4.zhimg.com/v2-bfe57fbee64b7d40c8f5f8d8c2a35d99_1440w.jpg",
        text: "Someone asks you why and whose disciple you are.\n\nYour answer is...",
        choices: [
          { text: "I believe in Han Feizi because he believes that harsh laws resolved all issues.", next: "the_evil_continues" },
          { text: "I believe in Mozi because he is good at manual techniques to make weapons so he should be a war lover and think humans are born evil.", next: "kicked_off" }
        ]
      },
      Good_attempt: {
        title: "Being Good",
        image: "https://images.unsplash.com/photo-1528360983277-13d401cdc186?w=800",
        text: "Someone agrees with you and asks you whose disciple you are.\n\nYour answer is...",
        choices: [
          { text: "Confucius and his student Mencius because they both highlight human being's integrity and benevolence and rulers with great virtue.", next: "being_good_continue" },
          { text: "Laozi, whose school is called Daoism. Daoism argues that people are good.", next: "continue_laozi" }
        ]
      },
      the_evil_continues: {
        title: "A Believer of Han Feizi",
        image: "https://images.gr-assets.com/authors/1445714416p5/1196500.jpg",
        text: "Yes, you are correct. Han Feizi believed that government should be based on law, prohibition, and punishment.\n\nENDING: Now you got the sense of Han Feizi, the founder of legalism in premodern China.",
        choices: []
      },
      kicked_off: {
        title: "The Rejection",
        image: "https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcS9wRcgWRkpCLYZKxBjQv15LTSgpC15KijMMpea8dCdlkgaLj-_n0tEaHU&s=10",
        text: "Mozi's disciples stand up and say you misunderstand Mozi. Mozi believes in universal love and argues against endless warfare.\n\nENDING: This path highlights that Confucius and Mozi share some thoughts on warfare and harmony between people.",
        choices: []
      },
      being_good_continue: {
        title: "Confucianism",
        image: "https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQlnSb4F69W3pA3WRDSrvIabiVzQBkFluZ0JpGxwEK7ffzxvtuxn6GGL0o&s=10",
        text: "You believe in Confucianism. You value rituals, propriety, good manners, and treating others with benevolence.\n\nENDING: This shows that you get the fundamental thoughts of Confucianism.",
        choices: []
      },
      continue_laozi: {
        title: "Daoism in detail",
        image: "https://img.visiontimes.com/2021/08/ThaySangLawCin.jpg",
        text: "Yes and No... Daoism believes that people should go back to a natural state of ignorance and contentment.\n\nENDING: This highlights that believed efforts to improve people failed; gov't should leave people alone.",
        choices: []
      }
    };

    let isTyping = false;

    function typeWriter(text, element, callback) {
      let i = 0;
      element.innerHTML = "";
      isTyping = true;
      function type() {
        if (i < text.length) {
          element.innerHTML += text.charAt(i);
          i++;
          setTimeout(type, 20);
        } else {
          isTyping = false;
          if (callback) callback();
        }
      }
      type();
    }

    function render(id) {
      const container = document.getElementById("game-container");
      const s = scenes[id];
      container.style.opacity = 0;

      setTimeout(() => {
        // Update Image
        const img = document.getElementById("scene-image");
        if (s.image) {
          img.src = s.image;
          img.style.display = "block";
        } else {
          img.style.display = "none";
        }

        document.getElementById("scene-title").textContent = s.title;
        const textEl = document.getElementById("scene-text");
        const box = document.getElementById("choices");
        box.innerHTML = "";
        container.style.opacity = 1;

        typeWriter(s.text, textEl, () => {
          if (!s.choices || s.choices.length === 0) {
            box.innerHTML = "<p style='text-align:center; font-style:italic;'>The story concludes here.</p>";
            return;
          }
          s.choices.forEach(c => {
            const btn = document.createElement("button");
            btn.textContent = c.text;
            btn.onclick = () => { if (!isTyping) render(c.next); };
            box.appendChild(btn);
          });
        });
      }, 500);
    }

    document.getElementById("restart-btn").onclick = () => render("start");
    render("start");
  </script>
</body>
</html>
"""

filename = "confucius_story_with_images.html"
with open(filename, "w", encoding="utf-8") as f:
    f.write(html_content)
print(f"Saved: {filename}")
# Out:
# Saved: confucius_story_with_images.html

# %%
from google.colab import files

# This will automatically trigger a download in your browser
files.download('confucius_story_with_images.html')
